# %% [markdown]
# Import the data and change the list on a DataFrame

# %%
import pandas as pd
d = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M', header = 0)
df = d[0]

# %% [markdown]
# Ignore the cells with a borough that is Not assigned

# %%
df_filtrer = df.drop(df[df['Borough']=="Not assigned"].index,axis=0)

# %% [markdown]
# Groupe the same value and Combined the rows with the neigborhoods separated with a comma

# %%
df_drop = df_filtrer.groupby("Postcode").agg(lambda x:','.join(set(x)))

# %%
df_drop.loc[df_drop['Neighbourhood']=='Not Assigned', 'Neighbourhood']=df_drop.loc[df_drop['Neighbourhood']=='Not Assigned', 'Borough']

# %%
df_drop.shape
# Out:
# (103, 2)

# %%
df_drop.head(103)
# Out:
#                    Borough                                      Neighbourhood
# Postcode
# M1B            Scarborough                                      Malvern,Rouge
# M1C            Scarborough               Highland Creek,Rouge Hill,Port Union
# M1E            Scarborough                    West Hill,Morningside,Guildwood
# M1G            Scarborough                                             Woburn
# M1H            Scarborough                                          Cedarbrae
# M1J            Scarborough                                Scarborough Village
# M1K            Scarborough          East Birchmount Park,Ionview,Kennedy Park
# M1L            Scarborough                      Golden Mile,Clairlea,Oakridge
# M1M            Scarborough      Scarborough Village West,Cliffcrest,Cliffside
# M1N            Scarborough                         Cliffside West,Birch Cliff
# M1P            Scarborough  Scarborough Town Centre,Dorset Park,Wexford He...
# M1R            Scarborough                                   Maryvale,Wexford
# M1S            Scarborough                                          Agincourt
# M1T            Scarborough              Sullivan,Tam O'Shanter,Clarks Corners
# M1V            Scarborough  Agincourt North,L'Amoreaux East,Milliken,Steel...
# M1W            Scarborough                                    L'Amoreaux West
# M1X            Scarborough                                        Upper Rouge
# M2H             North York                                  Hillcrest Village
# M2J             North York                         Fairview,Henry Farm,Oriole
# M2K             North York                                    Bayview Village
# M2L             North York                            Silver Hills,York Mills
# M2M             North York                             Willowdale,Newtonbrook
# M2N             North York                                   Willowdale South
# M2P             North York                                    York Mills West
# M2R             North York                                    Willowdale West
# M3A             North York                                          Parkwoods
# M3B             North York                                    Don Mills North
# M3C             North York                    Flemingdon Park,Don Mills South
# M3H             North York      Downsview North,Bathurst Manor,Wilson Heights
# M3J             North York                     Northwood Park,York University
# ...                    ...                                                ...
# M6C                   York                                 Humewood-Cedarvale
# M6E                   York                                Caledonia-Fairbanks
# M6G       Downtown Toronto                                           Christie
# M6H           West Toronto                        Dovercourt Village,Dufferin
# M6J           West Toronto                            Little Portugal,Trinity
# M6K           West Toronto         Brockton,Exhibition Place,Parkdale Village
# M6L             North York                   Upwood Park,Downsview,North Park
# M6M                   York        Mount Dennis,Silverthorn,Keelesdale,Del Ray
# M6N                   York                       The Junction North,Runnymede
# M6P           West Toronto                       The Junction South,High Park
# M6R           West Toronto                              Roncesvalles,Parkdale
# M6S           West Toronto                                  Swansea,Runnymede
# M7A           Queen's Park                                       Not assigned
# M7R            Mississauga              Canada Post Gateway Processing Centre
# M7Y           East Toronto  Business Reply Mail Processing Centre 969 Eastern
# M8V              Etobicoke         Humber Bay Shores,Mimico South,New Toronto
# M8W              Etobicoke                              Alderwood,Long Branch
# M8X              Etobicoke        Old Mill North,Montgomery Road,The Kingsway
# M8Y              Etobicoke  King's Mill Park,Mimico NE,Kingsway Park South...
# M8Z              Etobicoke  Kingsway Park South West,The Queensway West,Ro...
# M9A              Etobicoke                                   Islington Avenue
# M9B              Etobicoke  West Deane Park,Princess Gardens,Cloverdale,Ma...
# M9C              Etobicoke  Eringate,Markland Wood,Bloordale Gardens,Old B...
# M9L             North York                                      Humber Summit
# M9M             North York                                    Emery,Humberlea
# M9N                   York                                             Weston
# M9P              Etobicoke                                          Westmount
# M9R              Etobicoke  St. Phillips,Richview Gardens,Kingsview Villag...
# M9V              Etobicoke  Thistletown,South Steeles,Jamestown,Silverston...
# M9W              Etobicoke                                          Northwest
#
# [103 rows x 2 columns]

# %%
geo_data = pd.read_csv('http://cocl.us/Geospatial_data')

# %%
df_drop['Latitude'] = geo_data['Latitude'].values
df_drop['Longitude'] = geo_data['Latitude'].values
